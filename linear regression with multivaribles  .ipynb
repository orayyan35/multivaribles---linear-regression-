# %% [markdown]
#
#      y (The target or the variable we are trying to predict or
#      measure)
#
#      xs (The number of factors or independent variables)
#
#      n (The number of Xs we call it)
#
#      m (The number of rows)

# %%
# regression for price car 
x1= [5,5,6,7,7]# old car 
x2= [20,35,38,40,46] # power car 
x3= [6,6,8,8,10] # drum  

y=[114,120,123,121,135] # price 

# we have 5 car and 3 features 
# θ0 + θ1x1 + θ2x2+ ....... + θnxn

# %% [markdown]
#     X1 = [1,5,20,6]
#     X2 = [1,5,35,6]
#     X3 = [1,6,38,8]
#     X4 = [1,7,40,8]
#     X5 = [1,7,46,10]
#
#     Assume the value of theta
#     theta
#     θ0 = 5 ,θ1= 2 ,θ2 = 3  ,θ3 = 6

# %% [markdown]
# ![Screenshot%202023-09-15%20at%2011.36.41.png](attachment:Screenshot%202023-09-15%20at%2011.36.41.png)

# %% [markdown]
#  # θ0 + θ1x1 + θ2x2+ ....... + θnxn
#
#      X1 = [1,5,20,6]
#
#      #theta :-
#      θ0 = 5 ,θ1= 2 ,θ2 = 3  ,θ3 = 6
#
#     h(x1) = 5*1 + 2*5 +3*20 +6*6 = 111
#
#     X2 = [1,5,35,6]
#     #theta
#     θ0 = 5 ,θ1= 2 ,θ2 = 3  ,θ3 = 6
#
#     h(x2) = 5*1 + 2*5 +3*35 +6*6 = 119
#
#     X3 = [1,6,38,8]
#
#     Assume the value of theta
#     theta
#     θ0 = 5 ,θ1= 2 ,θ2 = 3  ,θ3 = 6
#
#     h(x3) = 5*1 + 2*6 +3*38 +6*8 = 127
#
#     X4 = [1,7,40,8]
#
#     Assume the value of theta
#     theta
#     θ0 = 5 ,θ1= 2 ,θ2 = 3  ,θ3 = 6
#
#     h(x4) = 5*1 + 2*7 +3*40 +6*8 = 122
#
#     X5 = [1,7,46,10]
#
#     Assume the value of theta
#     theta
#     θ0 = 5 ,θ1= 2 ,θ2 = 3  ,θ3 = 6
#
#     h(x5) = 5*1 + 2*7 +3*46 +6*10 = 140

# %% [markdown]
# This is an regression value = h(x)

# %% [markdown]
# ![Screenshot%202023-09-15%20at%2011.52.07.png](attachment:Screenshot%202023-09-15%20at%2011.52.07.png)

# %% [markdown]
#     value h(x) and value Y It is the one
#     that will modify the value of theta

# %% [markdown]
#     suppose :-
#     alpha  = 0.01
#     m=5
#     Assume the value of theta
#     theta
#     θ0 = 5 ,θ1= 2 ,θ2 = 3  ,θ3 = 6
#
#     theta0 = 5 -(0.01 / 5 )* [(111 - 114 ) + (119 - 120) + (127- 123)+
#     (122 - 121)+ (140 - 135) * (1)]   = 4.9
#
#     theta1 = 2 -(0.01 / 5 )* [(111 - 114 ) + (119 - 120) + (127- 123)+
#     (122 - 121)+ (140 - 135) * (5)]   = 2.6
#
#
#     theta2 = 3 -(0.01 / 5 )* [(111 - 114 ) + (119 - 120) + (127- 123)+
#     (122 - 121)+ (140 - 135) * (20)]   = 3.9
#
#     theta3 = 6 -(0.01 / 5 )* [(111 - 114 ) + (119 - 120) + (127- 123)+
#     (122 - 121)+ (140 - 135) * (6)]   = 6.4

# %% [markdown]
#     After we entered the values into the equation, we repeat the process     using the new theta result

# %% [markdown]
# new value theta =
# θ0 = 4.9 ,θ1= 2.6 ,θ2 = 3.9  ,θ3 = 6.4

# %% [markdown]
# # "I will keep trying different values for theta in the equation to reach the best prediction."
